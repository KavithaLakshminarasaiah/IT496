# %% [markdown]
# <a href="https://colab.research.google.com/github/KavithaLakshminarasaiah/IT496/blob/main/Kavitha_RiskAnalysis_Asn05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import numpy as np

riskDF=pd.DataFrame(columns=['Risk','Likelihood','Impact','Score'])
riskDF['Risk']=['Users','Team','Budget','Security']
riskDF['Likelihood'] =[0.2,0.3,0.1,0.5]
riskDF['Impact']=[1,2,7,10]
riskDF['Score']=riskDF['Impact']*riskDF['Likelihood']
print(riskDF)


ScorePivot=riskDF.pivot('Impact','Likelihood','Score')
print(ScorePivot)

labelsPivot=riskDF.pivot('Impact','Likelihood','Risk')
print(labelsPivot)


sns.set(rc={'figure.figsize':(8,8)})
p1=sns.heatmap(ScorePivot, cmap='hot_r',annot=labelsPivot, fmt='')
# Out:
#        Risk  Likelihood  Impact  Score
# 0     Users         0.2       1    0.2
# 1      Team         0.3       2    0.6
# 2    Budget         0.1       7    0.7
# 3  Security         0.5      10    5.0
# Likelihood  0.1  0.2  0.3  0.5
# Impact
# 1           NaN  0.2  NaN  NaN
# 2           NaN  NaN  0.6  NaN
# 7           0.7  NaN  NaN  NaN
# 10          NaN  NaN  NaN  5.0
# Likelihood     0.1    0.2   0.3       0.5
# Impact
# 1              NaN  Users   NaN       NaN
# 2              NaN    NaN  Team       NaN
# 7           Budget    NaN   NaN       NaN
# 10             NaN    NaN   NaN  Security
