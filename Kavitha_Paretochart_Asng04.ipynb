# %% [markdown]
# <a href="https://colab.research.google.com/github/KavithaLakshminarasaiah/IT496/blob/main/Kavitha_Asng04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt 
from matplotlib.ticker import PercentFormatter
df=pd.read_csv('/content/drive/MyDrive/skill.csv')
df.index=df['Skill']
df=df.sort_values(by='Frequency', ascending=False)
df["cumulativePercentage"] = df["Frequency"].cumsum()/df["Frequency"].sum()*100
df["cumulativePercentage"] = df["cumulativePercentage"].apply(lambda x:round(x,3))
print(df)


fig, ax = plt.subplots()

ax.bar(df.index, df["Frequency"], color="C3")

ax.set_xticklabels(df['Skill'], rotation=90)

ax2 = ax.twinx()

ax2.plot(df.index, df["cumulativePercentage"],color="C0", marker="D",ms=7, label = df["cumulativePercentage"])
ax2.yaxis.set_major_formatter(PercentFormatter())

ax.tick_params(axis="y", colors="C10")
ax2.tick_params(axis="y", colors="C10")

for index, v in df.iterrows():
  label = round(v['cumulativePercentage'],1)
  plt.annotate(label, xy=(v['Skill'],v['cumulativePercentage']))
  
plt.show()
# Out:
#                                                                            Skill  \
# Skill
# Competitive landscape knowledge                  Competitive landscape knowledge
# Industry Knowledge                                            Industry Knowledge
# Strategic Project Capability Skills          Strategic Project Capability Skills
# Process Centric Skills                                    Process Centric Skills
# Product Knowledge                                              Product Knowledge
# Organization Agility Skills                          Organization Agility Skills
# Technology Strategy/Adaptability Skills  Technology Strategy/Adaptability Skills
# Cross-Dimensional Competency Skills          Cross-Dimensional Competency Skills
# Business Environmental Skills                      Business Environmental Skills
# Technical Skills                                                Technical Skills
# ...
